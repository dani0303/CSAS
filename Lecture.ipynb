# %%
import pandas as pd

# %%
df = pd.read_csv("Data/Copy of COVID-19_Case_Surveillance_Public_Use_Data_with_Geography_20231228.csv", header = 0)
# Out:
# C:\Users\rodriguezd14\AppData\Local\Temp\ipykernel_3096\1459808291.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Data/Copy of COVID-19_Case_Surveillance_Public_Use_Data_with_Geography_20231228.csv", header = 0)

# %%
df = pd.read_csv("Data/Copy of COVID-19_Case_Surveillance_Public_Use_Data_with_Geography_20231228.csv", header = 0, low_memory = False)

# %%
df.head()
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 0    2022-01        MA               25  WORCESTER             25027
# 1    2020-12        MA               25    BRISTOL             25005
# 2    2022-06        MA               25    HAMPDEN             25013
# 3    2022-01        MA               25  HAMPSHIRE             25015
# 4    2022-07        MA               25    NORFOLK             25021
#
#         age_group     sex                           race        ethnicity  \
# 0  18 to 49 years    Male  American Indian/Alaska Native  Hispanic/Latino
# 1  18 to 49 years    Male                          Black  Hispanic/Latino
# 2  18 to 49 years    Male                          Black  Hispanic/Latino
# 3    0 - 17 years  Female                          White  Hispanic/Latino
# 4  18 to 49 years    Male                          White  Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# ...

# %%
df = pd.read_csv("Data/Copy of COVID-19_Case_Surveillance_Public_Use_Data_with_Geography_20231228.csv", header = 1, low_memory = False)

# %%
df.head()
# Out:
#    2022-01  MA  25  WORCESTER  25027  18 to 49 years    Male  \
# 0  2020-12  MA  25    BRISTOL  25005  18 to 49 years    Male
# 1  2022-06  MA  25    HAMPDEN  25013  18 to 49 years    Male
# 2  2022-01  MA  25  HAMPSHIRE  25015    0 - 17 years  Female
# 3  2022-07  MA  25    NORFOLK  25021  18 to 49 years    Male
# 4  2021-12  MA  25   PLYMOUTH  25023  18 to 49 years  Female
#
#   American Indian/Alaska Native  Hispanic/Latino    0  Unnamed: 10  Missing  \
# 0                         Black  Hispanic/Latino  0.0          NaN  Missing
# 1                         Black  Hispanic/Latino  0.0          NaN  Missing
# 2                         White  Hispanic/Latino  0.0          NaN  Missing
# 3                         White  Hispanic/Latino  0.0          NaN  Missing
# 4                       Unknown  Hispanic/Latino  0.0          NaN  Missing
#
#   Missing.1  Laboratory-confirmed case Missing.2 Missing.3 Missing.4  \
# ...

# %%
df = pd.read_csv("Data/Copy of COVID-19_Case_Surveillance_Public_Use_Data_with_Geography_20231228.csv", header = 0, low_memory = False)

# %%
df.head()
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 0    2022-01        MA               25  WORCESTER             25027
# 1    2020-12        MA               25    BRISTOL             25005
# 2    2022-06        MA               25    HAMPDEN             25013
# 3    2022-01        MA               25  HAMPSHIRE             25015
# 4    2022-07        MA               25    NORFOLK             25021
#
#         age_group     sex                           race        ethnicity  \
# 0  18 to 49 years    Male  American Indian/Alaska Native  Hispanic/Latino
# 1  18 to 49 years    Male                          Black  Hispanic/Latino
# 2  18 to 49 years    Male                          Black  Hispanic/Latino
# 3    0 - 17 years  Female                          White  Hispanic/Latino
# 4  18 to 49 years    Male                          White  Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1048575, 19)

# %%
df.dtypes
# Out:
# case_month                          object
# res_state                           object
# state_fips_code                      int64
# res_county                          object
# county_fips_code                     int64
# age_group                           object
# sex                                 object
# race                                object
# ethnicity                           object
# case_positive_specimen_interval    float64
# case_onset_interval                float64
# process                             object
# exposure_yn                         object
# current_status                      object
# symptom_status                      object
# hosp_yn                             object
# icu_yn                              object
# death_yn                            object
# underlying_conditions_yn            object
# dtype: object

# %%
df.columns
# Out:
# Index(['case_month', 'res_state', 'state_fips_code', 'res_county',
#        'county_fips_code', 'age_group', 'sex', 'race', 'ethnicity',
#        'case_positive_specimen_interval', 'case_onset_interval', 'process',
#        'exposure_yn', 'current_status', 'symptom_status', 'hosp_yn', 'icu_yn',
#        'death_yn', 'underlying_conditions_yn'],
#       dtype='object')

# %%
df["case_month"]
# Out:
# 0          2022-01
# 1          2020-12
# 2          2022-06
# 3          2022-01
# 4          2022-07
#             ...
# 1048570    2020-12
# 1048571    2022-09
# 1048572    2021-12
# 1048573    2022-01
# 1048574    2022-05
# Name: case_month, Length: 1048575, dtype: object

# %%
df[["case_month", "res_county", "age_group"]]
# Out:
#         case_month res_county       age_group
# 0          2022-01  WORCESTER  18 to 49 years
# 1          2020-12    BRISTOL  18 to 49 years
# 2          2022-06    HAMPDEN  18 to 49 years
# 3          2022-01  HAMPSHIRE    0 - 17 years
# 4          2022-07    NORFOLK  18 to 49 years
# ...            ...        ...             ...
# 1048570    2020-12    SUFFOLK  18 to 49 years
# 1048571    2022-09  WORCESTER       65+ years
# 1048572    2021-12    HAMPDEN    0 - 17 years
# 1048573    2022-01    NORFOLK  18 to 49 years
# 1048574    2022-05    BRISTOL  50 to 64 years
#
# [1048575 rows x 3 columns]

# %%
type(['case_month', 'res_county', 'age_group'])
# Out:
# list

# %%
x = ['case_month', 'res_county', 'age_group']

# %%
print(x)
# Out:
# ['case_month', 'res_county', 'age_group']

# %%
df.head(2)
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 0    2022-01        MA               25  WORCESTER             25027
# 1    2020-12        MA               25    BRISTOL             25005
#
#         age_group   sex                           race        ethnicity  \
# 0  18 to 49 years  Male  American Indian/Alaska Native  Hispanic/Latino
# 1  18 to 49 years  Male                          Black  Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# 0                              0.0                  NaN  Missing     Missing
# 1                              0.0                  NaN  Missing     Missing
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 1  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN

# %%
df.rename(columns={'res_state':'Residential State'})
# Out:
#         case_month Residential State  state_fips_code res_county  \
# 0          2022-01                MA               25  WORCESTER
# 1          2020-12                MA               25    BRISTOL
# 2          2022-06                MA               25    HAMPDEN
# 3          2022-01                MA               25  HAMPSHIRE
# 4          2022-07                MA               25    NORFOLK
# ...            ...               ...              ...        ...
# 1048570    2020-12                MA               25    SUFFOLK
# 1048571    2022-09                MA               25  WORCESTER
# 1048572    2021-12                MA               25    HAMPDEN
# 1048573    2022-01                MA               25    NORFOLK
# 1048574    2022-05                MA               25    BRISTOL
#
#          county_fips_code       age_group     sex  \
# 0                   25027  18 to 49 years    Male
# 1                   25005  18 to 49 years    Male
# ...

# %%
df.rename(columns={'res_county':'Residential County', 'res_state':'Residential State'})
# Out:
#         case_month Residential State  state_fips_code Residential County  \
# 0          2022-01                MA               25          WORCESTER
# 1          2020-12                MA               25            BRISTOL
# 2          2022-06                MA               25            HAMPDEN
# 3          2022-01                MA               25          HAMPSHIRE
# 4          2022-07                MA               25            NORFOLK
# ...            ...               ...              ...                ...
# 1048570    2020-12                MA               25            SUFFOLK
# 1048571    2022-09                MA               25          WORCESTER
# 1048572    2021-12                MA               25            HAMPDEN
# 1048573    2022-01                MA               25            NORFOLK
# 1048574    2022-05                MA               25            BRISTOL
#
#          county_fips_code       age_group     sex  \
# ...

# %%
df.iloc[1,7]
# Out:
# 'Black'

# %%
df.iloc[1,:]
# Out:
# case_month                                           2020-12
# res_state                                                 MA
# state_fips_code                                           25
# res_county                                           BRISTOL
# county_fips_code                                       25005
# age_group                                     18 to 49 years
# sex                                                     Male
# race                                                   Black
# ethnicity                                    Hispanic/Latino
# case_positive_specimen_interval                          0.0
# case_onset_interval                                      NaN
# process                                              Missing
# exposure_yn                                          Missing
# current_status                     Laboratory-confirmed case
# symptom_status                                       Missing
# ...

# %%
df.iloc[:,1]
# Out:
# 0          MA
# 1          MA
# 2          MA
# 3          MA
# 4          MA
#            ..
# 1048570    MA
# 1048571    MA
# 1048572    MA
# 1048573    MA
# 1048574    MA
# Name: res_state, Length: 1048575, dtype: object

# %%
df.iloc[[1], :]
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 1    2020-12        MA               25    BRISTOL             25005
#
#         age_group   sex   race        ethnicity  \
# 1  18 to 49 years  Male  Black  Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# 1                              0.0                  NaN  Missing     Missing
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 1  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#   underlying_conditions_yn
# 1                      NaN

# %%
df.iloc[[1,3],:]
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 1    2020-12        MA               25    BRISTOL             25005
# 3    2022-01        MA               25  HAMPSHIRE             25015
#
#         age_group     sex   race        ethnicity  \
# 1  18 to 49 years    Male  Black  Hispanic/Latino
# 3    0 - 17 years  Female  White  Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# 1                              0.0                  NaN  Missing     Missing
# 3                              0.0                  NaN  Missing     Missing
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 1  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 3  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#   underlying_conditions_yn
# 1                      NaN
# 3                      NaN

# %%
df.iloc[2:5,:]
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 2    2022-06        MA               25    HAMPDEN             25013
# 3    2022-01        MA               25  HAMPSHIRE             25015
# 4    2022-07        MA               25    NORFOLK             25021
#
#         age_group     sex   race        ethnicity  \
# 2  18 to 49 years    Male  Black  Hispanic/Latino
# 3    0 - 17 years  Female  White  Hispanic/Latino
# 4  18 to 49 years    Male  White  Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# 2                              0.0                  NaN  Missing     Missing
# 3                              0.0                  NaN  Missing     Missing
# 4                              0.0                  NaN  Missing     Missing
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 2  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# ...

# %%
df.loc[2, 'res_county']
# Out:
# 'HAMPDEN'

# %%
df.loc[:, 'res_county']
# Out:
# 0          WORCESTER
# 1            BRISTOL
# 2            HAMPDEN
# 3          HAMPSHIRE
# 4            NORFOLK
#              ...
# 1048570      SUFFOLK
# 1048571    WORCESTER
# 1048572      HAMPDEN
# 1048573      NORFOLK
# 1048574      BRISTOL
# Name: res_county, Length: 1048575, dtype: object

# %%
df.loc[2:4, ['res_state', 'res_county', 'age_group']]
# Out:
#   res_state res_county       age_group
# 2        MA    HAMPDEN  18 to 49 years
# 3        MA  HAMPSHIRE    0 - 17 years
# 4        MA    NORFOLK  18 to 49 years

# %%
df.head(4)
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 0    2022-01        MA               25  WORCESTER             25027
# 1    2020-12        MA               25    BRISTOL             25005
# 2    2022-06        MA               25    HAMPDEN             25013
# 3    2022-01        MA               25  HAMPSHIRE             25015
#
#         age_group     sex                           race        ethnicity  \
# 0  18 to 49 years    Male  American Indian/Alaska Native  Hispanic/Latino
# 1  18 to 49 years    Male                          Black  Hispanic/Latino
# 2  18 to 49 years    Male                          Black  Hispanic/Latino
# 3    0 - 17 years  Female                          White  Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# 0                              0.0                  NaN  Missing     Missing
# 1                              0.0                  NaN  Missing     Missing
# ...

# %%
df.describe()
# Out:
#        state_fips_code  county_fips_code  case_positive_specimen_interval  \
# count        1048575.0      1.048575e+06                     1.044100e+06
# mean              25.0      2.501576e+04                     5.891390e-02
# std                0.0      8.253886e+00                     7.997071e-01
# min               25.0      2.500100e+04                    -6.900000e+01
# 25%               25.0      2.500900e+04                     0.000000e+00
# 50%               25.0      2.501700e+04                     0.000000e+00
# 75%               25.0      2.502300e+04                     0.000000e+00
# max               25.0      2.502700e+04                     1.210000e+02
#
#        case_onset_interval
# count        142125.000000
# mean              0.063282
# std               1.181488
# min             -21.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max              63.000000

# %%
df['case_month'].unique()
# Out:
# array(['2022-01', '2020-12', '2022-06', '2022-07', '2021-12', '2021-01',
#        '2021-08', '2022-12', '2022-04', '2023-01', '2021-11', '2021-10',
#        '2023-04', '2022-02', '2023-03', '2021-03', '2022-05', '2023-02',
#        '2023-10', '2020-05', '2020-08', '2023-05', '2023-09', '2022-03',
#        '2023-08', '2023-07', '2023-11', '2022-09', '2020-09', '2020-11',
#        '2020-10', '2022-08', '2020-06', '2021-09', '2021-07', '2022-11',
#        '2023-06', '2020-04', '2021-04', '2021-02', '2020-03', '2021-05',
#        '2020-07', '2022-10', '2021-06', '2020-02', '2020-01'],
#       dtype=object)

# %%
df['case_month'].unique()
# Out:
# array(['2022-01', '2020-12', '2022-06', '2022-07', '2021-12', '2021-01',
#        '2021-08', '2022-12', '2022-04', '2023-01', '2021-11', '2021-10',
#        '2023-04', '2022-02', '2023-03', '2021-03', '2022-05', '2023-02',
#        '2023-10', '2020-05', '2020-08', '2023-05', '2023-09', '2022-03',
#        '2023-08', '2023-07', '2023-11', '2022-09', '2020-09', '2020-11',
#        '2020-10', '2022-08', '2020-06', '2021-09', '2021-07', '2022-11',
#        '2023-06', '2020-04', '2021-04', '2021-02', '2020-03', '2021-05',
#        '2020-07', '2022-10', '2021-06', '2020-02', '2020-01'],
#       dtype=object)

# %%
df['age_group'].unique()
# Out:
# array(['18 to 49 years', '0 - 17 years', '50 to 64 years', '65+ years',
#        nan, 'Missing'], dtype=object)

# %%
df['res_county'].unique()
# Out:
# array(['WORCESTER', 'BRISTOL', 'HAMPDEN', 'HAMPSHIRE', 'NORFOLK',
#        'PLYMOUTH', 'SUFFOLK', 'BARNSTABLE', 'MIDDLESEX', 'ESSEX',
#        'BERKSHIRE', 'FRANKLIN'], dtype=object)

# %%
df['ethnicity'].unique()
# Out:
# array(['Hispanic/Latino', 'Non-Hispanic/Latino', 'Missing', nan,
#        'Unknown'], dtype=object)

# %%
df.head(4)
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 0    2022-01        MA               25  WORCESTER             25027
# 1    2020-12        MA               25    BRISTOL             25005
# 2    2022-06        MA               25    HAMPDEN             25013
# 3    2022-01        MA               25  HAMPSHIRE             25015
#
#         age_group     sex                           race        ethnicity  \
# 0  18 to 49 years    Male  American Indian/Alaska Native  Hispanic/Latino
# 1  18 to 49 years    Male                          Black  Hispanic/Latino
# 2  18 to 49 years    Male                          Black  Hispanic/Latino
# 3    0 - 17 years  Female                          White  Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# 0                              0.0                  NaN  Missing     Missing
# 1                              0.0                  NaN  Missing     Missing
# ...

# %%
df.shape
# Out:
# (1048575, 19)

# %%
df.shape[0]
# Out:
# 1048575

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Length: 1048575, dtype: bool

# %%
sum(df.duplicated())
# Out:
# 950734

# %%
df.duplicated().sum()
# Out:
# 950734

# %%
sum(df.duplicated(subset=['case_month']))
# Out:
# 1048528

# %%
sum(df.duplicated(subset=['case_month','res_county','age_group']))
# Out:
# 1046294

# %%
df.isnull()
# Out:
#          case_month  res_state  state_fips_code  res_county  county_fips_code  \
# 0             False      False            False       False             False
# 1             False      False            False       False             False
# 2             False      False            False       False             False
# 3             False      False            False       False             False
# 4             False      False            False       False             False
# ...             ...        ...              ...         ...               ...
# 1048570       False      False            False       False             False
# 1048571       False      False            False       False             False
# 1048572       False      False            False       False             False
# 1048573       False      False            False       False             False
# 1048574       False      False            False       False             False
#
# ...

# %%
df['res_county'].isnull()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# Name: res_county, Length: 1048575, dtype: bool

# %%
df['res_county'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# case_month                               0
# res_state                                0
# state_fips_code                          0
# res_county                               0
# county_fips_code                         0
# age_group                             3713
# sex                                   9803
# race                                265156
# ethnicity                           306518
# case_positive_specimen_interval       4475
# case_onset_interval                 906450
# process                                  0
# exposure_yn                              0
# current_status                           0
# symptom_status                           0
# hosp_yn                                  0
# icu_yn                                   0
# death_yn                             24522
# underlying_conditions_yn           1048557
# dtype: int64

# %%
df['ethnicity'].isnull()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# Name: ethnicity, Length: 1048575, dtype: bool

# %%
df.isnull()
# Out:
#          case_month  res_state  state_fips_code  res_county  county_fips_code  \
# 0             False      False            False       False             False
# 1             False      False            False       False             False
# 2             False      False            False       False             False
# 3             False      False            False       False             False
# 4             False      False            False       False             False
# ...             ...        ...              ...         ...               ...
# 1048570       False      False            False       False             False
# 1048571       False      False            False       False             False
# 1048572       False      False            False       False             False
# 1048573       False      False            False       False             False
# 1048574       False      False            False       False             False
#
# ...

# %%
df.isnull().sum(axis=1)
# Out:
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
#           ..
# 1048570    2
# 1048571    2
# 1048572    2
# 1048573    2
# 1048574    2
# Length: 1048575, dtype: int64

# %%
df.isnull().sum(axis=1)[2]
# Out:
# 2

# %%
df.isnull().sum(axis=1)==0
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# Length: 1048575, dtype: bool

# %%
df[df.isnull().sum(axis=1)==0]
# Out:
#        case_month res_state  state_fips_code res_county  county_fips_code  \
# 27904     2020-12        MA               25   FRANKLIN             25011
# 44082     2021-09        MA               25  BERKSHIRE             25003
# 86376     2021-04        MA               25    BRISTOL             25005
# 372112    2020-03        MA               25    HAMPDEN             25013
# 418467    2020-04        MA               25  BERKSHIRE             25003
# 507718    2020-11        MA               25      ESSEX             25009
#
#              age_group     sex     race            ethnicity  \
# 27904   18 to 49 years  Female  Unknown              Unknown
# 44082        65+ years    Male    White  Non-Hispanic/Latino
# 86376   18 to 49 years    Male    White  Non-Hispanic/Latino
# 372112  50 to 64 years    Male    White  Non-Hispanic/Latino
# 418467  18 to 49 years  Female    White  Non-Hispanic/Latino
# 507718       65+ years  Female    White  Non-Hispanic/Latino
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   case_month                       1048575 non-null  object
#  1   res_state                        1048575 non-null  object
#  2   state_fips_code                  1048575 non-null  int64
#  3   res_county                       1048575 non-null  object
#  4   county_fips_code                 1048575 non-null  int64
#  5   age_group                        1044862 non-null  object
#  6   sex                              1038772 non-null  object
#  7   race                             783419 non-null   object
#  8   ethnicity                        742057 non-null   object
#  9   case_positive_specimen_interval  1044100 non-null  float64
#  10  case_onset_interval              142125 non-null   float64
# ...

# %%
df['case_month'] = pd.to_datetime(df['case_month'])

# %%
df_sorted = df.sort_values(by='case_month')

# %%
df_sorted.head()
# Out:
#        case_month res_state  state_fips_code res_county  county_fips_code  \
# 726292 2020-01-01        MA               25  MIDDLESEX             25017
# 726277 2020-01-01        MA               25  MIDDLESEX             25017
# 726300 2020-01-01        MA               25  MIDDLESEX             25017
# 726307 2020-01-01        MA               25  MIDDLESEX             25017
# 726316 2020-01-01        MA               25  MIDDLESEX             25017
#
#        age_group  sex race ethnicity  case_positive_specimen_interval  \
# 726292       NaN  NaN  NaN       NaN                             52.0
# 726277       NaN  NaN  NaN       NaN                              NaN
# 726300       NaN  NaN  NaN       NaN                             53.0
# 726307       NaN  NaN  NaN       NaN                             18.0
# 726316       NaN  NaN  NaN       NaN                             52.0
#
#         case_onset_interval  process exposure_yn             current_status  \
# ...

# %%
df_sorted['case_month'] > pd.to_datetime('2023-04')
# Out:
# 726292     False
# 726277     False
# 726300     False
# 726307     False
# 726316     False
#            ...
# 427336      True
# 353193      True
# 353203      True
# 699851      True
# 1029085     True
# Name: case_month, Length: 1048575, dtype: bool

# %%
(5>3) and (6>1)
# Out:
# True

# %%
 (df_sorted['case_month'] > pd.to_datetime('2023-04')) and (df_sorted['case_month'] < pd.to_datetime('2023-09'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3096\214409367.py in ?()
# ----> 1 (df_sorted['case_month'] > pd.to_datetime('2023-04')) and (df_sorted['case_month'] < pd.to_datetime('2023-09'))
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
 (df_sorted['case_month'] > pd.to_datetime('2023-04')) & (df_sorted['case_month'] < pd.to_datetime('2023-09'))
# Out:
# 726292     False
# 726277     False
# 726300     False
# 726307     False
# 726316     False
#            ...
# 427336     False
# 353193     False
# 353203     False
# 699851     False
# 1029085    False
# Name: case_month, Length: 1048575, dtype: bool

# %%
 (df_sorted['case_month'] > pd.to_datetime('2023-04')) & (df_sorted['case_month'] < pd.to_datetime('2023-09'))
# Out:
# 726292     False
# 726277     False
# 726300     False
# 726307     False
# 726316     False
#            ...
# 427336     False
# 353193     False
# 353203     False
# 699851     False
# 1029085    False
# Name: case_month, Length: 1048575, dtype: bool

# %%
condition =  (df_sorted['case_month'] > pd.to_datetime('2023-04')) & (df_sorted['case_month'] < pd.to_datetime('2023-09'))

# %%
df_filtered_by_month_2 = df_sorted[condition]

# %%
df_filtered_by_month_2.head(4)
# Out:
#         case_month res_state  state_fips_code res_county  county_fips_code  \
# 632498  2023-05-01        MA               25    HAMPDEN             25013
# 1046738 2023-05-01        MA               25  WORCESTER             25027
# 961545  2023-05-01        MA               25      ESSEX             25009
# 699574  2023-05-01        MA               25    BRISTOL             25005
#
#               age_group     sex   race            ethnicity  \
# 632498   18 to 49 years  Female    NaN                  NaN
# 1046738  50 to 64 years    Male  White  Non-Hispanic/Latino
# 961545        65+ years    Male    NaN                  NaN
# 699574   18 to 49 years    Male    NaN                  NaN
#
#          case_positive_specimen_interval  case_onset_interval  process  \
# 632498                               0.0                  NaN  Missing
# 1046738                              0.0                  NaN  Missing
# 961545                               0.0                  NaN  Missing
# ...

# %%
df_filtered_by_month_2.shape
# Out:
# (12691, 19)

# %%
condition_2 = (df_sorted['case_month'] > pd.to_datetime('2023-04')) & (df_sorted['age_group'] == '50 to 64 years')

# %%
df_filtered_by_month_and_age_group = df_sorted[condition_2]

# %%
df_filtered_by_month_and_age_group.head(4)
# Out:
#         case_month res_state  state_fips_code res_county  county_fips_code  \
# 1046738 2023-05-01        MA               25  WORCESTER             25027
# 1042492 2023-05-01        MA               25      ESSEX             25009
# 1042516 2023-05-01        MA               25      ESSEX             25009
# 1046730 2023-05-01        MA               25  WORCESTER             25027
#
#               age_group     sex   race            ethnicity  \
# 1046738  50 to 64 years    Male  White  Non-Hispanic/Latino
# 1042492  50 to 64 years  Female    NaN                  NaN
# 1042516  50 to 64 years  Female    NaN                  NaN
# 1046730  50 to 64 years    Male  White  Non-Hispanic/Latino
#
#          case_positive_specimen_interval  case_onset_interval  process  \
# 1046738                              0.0                  NaN  Missing
# 1042492                              0.0                  NaN  Missing
# 1042516                              0.0                  NaN  Missing
# ...

# %%
df_filtered_by_month_and_age_group.shape
# Out:
# (4972, 19)
