# %%
import pandas as pd

# %%
df = pd.read_csv("Data/ad_viz_plotval_data.csv", header=0, low_memory=False)

# %%
df.head(7)
# Out:
#          Date Source    Site ID  POC  Daily Max 8-hour CO Concentration UNITS  \
# 0  01/01/2023    AQS  250250042    1                                0.2   ppm
# 1  01/02/2023    AQS  250250042    1                                0.7   ppm
# 2  01/03/2023    AQS  250250042    1                                0.7   ppm
# 3  01/04/2023    AQS  250250042    1                                0.5   ppm
# 4  01/05/2023    AQS  250250042    1                                0.2   ppm
# 5  01/06/2023    AQS  250250042    1                                0.3   ppm
# 6  01/07/2023    AQS  250250042    1                                0.3   ppm
#
#    DAILY_AQI_VALUE              Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0                2  DUDLEY SQUARE ROXBURY               17              71.0
# 1                8  DUDLEY SQUARE ROXBURY               24             100.0
# 2                8  DUDLEY SQUARE ROXBURY               24             100.0
# ...

# %%
df.tail(7)
# Out:
#            Date Source    Site ID  POC  Daily Max 8-hour CO Concentration  \
# 765  09/24/2023    AQS  250270023    1                                0.2
# 766  09/25/2023    AQS  250270023    1                                0.3
# 767  09/26/2023    AQS  250270023    1                                0.3
# 768  09/27/2023    AQS  250270023    1                                0.4
# 769  09/28/2023    AQS  250270023    1                                0.4
# 770  09/29/2023    AQS  250270023    1                                0.4
# 771  09/30/2023    AQS  250270023    1                                0.3
#
#     UNITS  DAILY_AQI_VALUE                Site Name  DAILY_OBS_COUNT  \
# 765   ppm                2  WORCESTER SUMMER STREET               24
# 766   ppm                3  WORCESTER SUMMER STREET               24
# 767   ppm                3  WORCESTER SUMMER STREET               24
# 768   ppm                5  WORCESTER SUMMER STREET               24
# ...

# %%
df.shape
# Out:
# (772, 20)

# %%
df.dtypes
# Out:
# Date                                  object
# Source                                object
# Site ID                                int64
# POC                                    int64
# Daily Max 8-hour CO Concentration    float64
# UNITS                                 object
# DAILY_AQI_VALUE                        int64
# Site Name                             object
# DAILY_OBS_COUNT                        int64
# PERCENT_COMPLETE                     float64
# AQS_PARAMETER_CODE                     int64
# AQS_PARAMETER_DESC                    object
# CBSA_CODE                              int64
# CBSA_NAME                             object
# STATE_CODE                             int64
# STATE                                 object
# COUNTY_CODE                            int64
# COUNTY                                object
# SITE_LATITUDE                        float64
# SITE_LONGITUDE                       float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Max 8-hour CO Concentration',
#        'UNITS', 'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT',
#        'PERCENT_COMPLETE', 'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC',
#        'CBSA_CODE', 'CBSA_NAME', 'STATE_CODE', 'STATE', 'COUNTY_CODE',
#        'COUNTY', 'SITE_LATITUDE', 'SITE_LONGITUDE'],
#       dtype='object')

# %%
df.iloc[0:7, [0,4,6,17]]
# Out:
#          Date  Daily Max 8-hour CO Concentration  DAILY_AQI_VALUE   COUNTY
# 0  01/01/2023                                0.2                2  Suffolk
# 1  01/02/2023                                0.7                8  Suffolk
# 2  01/03/2023                                0.7                8  Suffolk
# 3  01/04/2023                                0.5                6  Suffolk
# 4  01/05/2023                                0.2                2  Suffolk
# 5  01/06/2023                                0.3                3  Suffolk
# 6  01/07/2023                                0.3                3  Suffolk
